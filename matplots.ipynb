Loss_list= [209050885584.0, 32002169846.0, 13106552737.75, 7034166664.75, 3953371860.0, 2773864110.25, 2378291280.5, 1971472029.0, 1541103131.25, 1268602871.25, 1177582977.0, 910472169.78125, 915321467.25, 808132602.0, 692092348.75, 787416683.5, 749406741.40625, 656133989.9375, 483088577.0, 458617109.75, 396331542.0, 501769080.0, 540432367.75, 687315426.375, 320308056.75, 321493674.125, 288822541.625, 236038036.3125, 462805603.875, 309011599.71875, 265861798.1875, 186157329.375, 288054308.0, 257756888.25, 130403348.75, 342002337.46875, 197300602.4375, 226797629.1875, 186902756.75, 754699508.8125, 181191362.125, 36010002.34375, 211994495.5, 133286877.0, 183836748.828125, 190073939.0, 204301741.75, 190687524.375, 321563907.5625, 173646835.125, 75164462.5, 181023894.0, 175657357.5, 172759332.25, 149639265.75, 312767166.5625, 97280309.25, 177710769.5, 46398411.75, 144551522.5, 163946843.6875, 99443234.125, 67220466.3125, 178873351.3125, 91981207.625, 156489419.49609375, 150175815.125, 53347010.125, 111287202.453125, 137963486.5, 89789575.25, 95685248.46875, 122745280.0, 195446174.5, 76126803.75, 80275535.75, 101889298.6875, 128126177.0, 182912659.75, 22582156.25, 140113454.0, 163587388.0, 140204307.0, 110268239.625, 74159770.75, 67278304.75, 66912289.5, 155473798.75, 52161475.28125, 154296612.0625, 82668446.875, 21764813.5, 108317464.125, 45348395.5, 74085682.25, 150095392.25, 218133486.0, 110646660.5, 126729375.0, 160776626.25]

# %%
epochs=[i+1 for i in range(100)]

# %%
plt.plot(epochs, Accuracy_training_list)
plt.plot(epochs, Accuracy_test_list)
axes = plt.gca()
axes.set_xlim([0,100])
axes.set_ylim([0,1.1])
# Out:
# (0.0, 1.1)

# %%
plt.plot(epochs, Accuracy_test_list)

# %%
plt.plot(epochs, Loss_list)
axes = plt.gca()
axes.set_xlim([0,20])
# Out:
# (0.0, 20.0)

# %%
import numpy as np

# %%
fsize=10
fig_A = plt.figure('Two compartments')
ax_A = fig_A.add_subplot(111)
#ax.scatter(treatmentData['time[min]'],avgLevel,facecolor='#FFC000') fmt='.k',mfc='k',ecolor='k',label='Total DOX'
#ax_A.errorbar(treatmentData['time[min]'],avgDrugLevel,yerr=stdDrugLevel, fmt='s', elinewidth=0.5, mfc='k',ecolor='k', color='k', label='Total DOX')
ax_A.plot(epochs,Loss_list,color='k',label='Loss')
#ax_A.errorbar(treatmentData['time[min]'],avgLipidLevel,yerr=stdLipidLevel,fmt='o', elinewidth=0.5, mfc='darkgray',ecolor='k', color='k', label='DPPGOG')
#ax_A.plot(epochs,Accuracy_test_list,color='b',label='Accuracy_testing')
#ax_A.plot(fitX_Lipid,fitY2_Lipid,color='k',linestyle ='--',label='DPPGOG cauchy fit')
#ax_A.fill_betweenx([(-0.1),1.1],0,20,facecolor='lightgray',edgecolor='face')
#ax_A.fill_betweenx([-10,10],60,90,facecolor='lightgray',edgecolor='face')


ax_A.set_xbound(0,100)
ax_A.set_xticks(np.arange(0,100,5,))
#ax_A.set_ybound((-0.1),1.1)
ax_A.tick_params(labelsize=fsize)
ax_A.set_xlabel('epoch',fontsize=fsize)
ax_A.set_ylabel('Loss',fontsize=fsize)

handles,labels = ax_A.get_legend_handles_labels()
order = [0]
#order = [5,4,2,3,0,1]
orderedHandles = [handles[i] for i in order]
orderedLables = [labels[i] for i in order]

fig_A.tight_layout()

ax_A.legend(orderedHandles,orderedLables,loc='upper right',ncol=1,fontsize = 10)
